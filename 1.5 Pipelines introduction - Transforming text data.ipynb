# %%
from utils import css_from_file
css_from_file('style/style.css')
# Out:
# <style>/*@font-face {
# 	font-family: "Computer Modern";
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
# }
# @font-face {
# 	font-family: "Computer Modern";
# 	font-weight: bold;
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
# }
# @font-face {
# 	font-family: "Computer Modern";
# 	font-style: oblique;
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
# }
# @font-face {
# 	font-family: "Computer Modern";
# 	font-weight: bold;
# 	font-style: oblique;
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
# }*/
#
# .navbar-brand, .current_kernel_logo {display:none}
# .container {
#     width:80%;
# }
#
# h1 {
# 	font-family: Helvetica, serif;
# }
# h4{
# 	margin-top:12px;
# 	margin-bottom: 3px;
#    }
# div.text_cell_render{
# 	font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
# 	line-height: 145%;
# 	font-size: 100%;
# 	width:100%;
# 	margin-left:auto;
# 	margin-right:auto;
# }
# .CodeMirror{
# 		font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
# }
# .text_cell_render h5 {
# 	font-weight: 300;
# 	font-size: 22pt;
# 	/*color: #4057A1;*/
# 	font-style: italic;
# 	margin-bottom: .5em;
# 	margin-top: 0.5em;
# 	display: block;
# }
#
# .warning{
# 	color: rgb( 240, 20, 20 )
# 	}
#
# div.spoiler {
# 	display: none;
# }
#
# .rendered_html code {
# 	border: 0;
# 	/*background-color: #eee;*/
# 	font-size: 100%;
# 	padding: 1px 2px;
# }
# </style>

# %%
import re
import pandas as pd
import numpy as np

from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import (
    CountVectorizer, TfidfVectorizer, HashingVectorizer
)

import warnings
warnings.filterwarnings("ignore")
# Out:
# /home/ramya/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Read csv file into a dataframe

# %%
df = pd.read_csv("data/ebaytitles.csv")
df = df.sample(frac=0.1) # delete this line if you are brave and have many GBs of RAM
df.head()
#df.count()
# Out:
#                                                     title  \
# 257551  Hotpoint RFA52S RFA52T RFAA52 Fridge Freezer T...
# 907037                                 wonderland NEW DVD
# 100600  New Ladies Womens Designer Style Leather Tote ...
# 77339        1x NGK Copper Core Spark Plug BKR6EZ  (4619)
# 511926  'Floral Butterflies' Fashion Case for GALAXY S...
#
#                         category_name
# 257551          Home, Furniture & DIY
# 907037               DVDs, Films & TV
# 100600   Clothes, Shoes & Accessories
# 77339     Vehicle Parts & Accessories
# 511926  Mobile Phones & Communication

# %% [markdown]
# Print out unique values of a column

# %%
df.category_name.unique()
# Out:
# array(['Vehicle Parts & Accessories', 'Home, Furniture & DIY', 'Music',
#        'Clothes, Shoes & Accessories', 'Computers/Tablets & Networking',
#        'Pottery, Porcelain & Glass', 'Cameras & Photography',
#        'DVDs, Films & TV', 'Baby', 'Collectibles', 'Crafts',
#        'Business, Office & Industrial', 'Sporting Goods',
#        'Mobile Phones & Communication', 'Jewellery & Watches',
#        'Toys & Games', 'Sound & Vision', 'Garden & Patio',
#        'Sports Memorabilia', 'Video Games & Consoles',
#        'Musical Instruments & Gear', 'Health & Beauty', 'Antiques',
#        'Coins & Paper Money', 'Art', 'Everything Else',
#        'Books, Comics & Magazines', 'Pet Supplies', 'Stamps',
#        'Dolls & Bears', 'Consumer Electronics',
#        'Cell Phones & Accessories', 'Wholesale & Job Lots',
#        'Entertainment Memorabilia', 'Travel', 'Holidays & Travel',
#        'Events Tickets'], dtype=object)

# %% [markdown]
# Split the data into train and test observations - there is a column

# %%
X = df.title.values
y = df.category_name.values

X_tr, X_te, y_tr, y_te = train_test_split(X, 
                                          y,
                                          test_size=0.1,
                                          random_state=0)

# %% [markdown]
# Exercise
# ------------------
#
# 1. Count how many titles are in each category (```pandas.DataFrame.groupby```). Print out most common at the top

# %%
##########################
# put your solution here #
##########################
df.groupby("category_name")["title"].count().sort_values(ascending = False)
# Out:
# category_name
# Vehicle Parts & Accessories       23158
# Clothes, Shoes & Accessories      16857
# Home, Furniture & DIY             12811
# Computers/Tablets & Networking     6771
# Jewellery & Watches                6122
# Sporting Goods                     4686
# Mobile Phones & Communication      3952
# Crafts                             3403
# Health & Beauty                    3346
# Toys & Games                       2946
# Business, Office & Industrial      2761
# Collectibles                       2517
# Sound & Vision                     1910
# Music                              1346
# Garden & Patio                     1067
# Cameras & Photography               861
# Pet Supplies                        694
# Baby                                675
# DVDs, Films & TV                    594
# Art                                 563
# Musical Instruments & Gear          446
# Video Games & Consoles              435
# Books, Comics & Magazines           433
# Dolls & Bears                       292
# Sports Memorabilia                  275
# Coins & Paper Money                 211
# Everything Else                     175
# Antiques                            172
# Consumer Electronics                132
# Stamps                              105
# Pottery, Porcelain & Glass          104
# Wholesale & Job Lots                 90
# Cell Phones & Accessories            77
# Entertainment Memorabilia             8
# Holidays & Travel                     3
# Travel                                2
# Name: title, dtype: int64

# %% [markdown]
# <a>Double click to show the solution</a>
# <div class='spoiler'>
#
# frequencies = df.groupby("category_name")["title"].count()
# frequencies.sort_values(inplace=True,ascending=False)
# print(frequencies)
#
# </div>

# %% [markdown]
# Bag of words
# --------------------
#
# Different types of vectorizers:
#
# <ul>
# <li>```sklearn.feature_extraction.text.CountVectorizer``` - Counts the number of times a word appears in the text</li>
# <li>```sklearn.feature_extraction.text.TfidfVectorizer``` - Weighs the words according to the importance of the word in the context of whole collection. Is the word ```the``` important if it appears in all documents?</li>
# <li>```sklearn.feature_extraction.text.HashingVectorizer``` - Useful when you don't know the vocabulary upfront. Feature number is calculated as ```hash(token) % vocabulary_size```.</li>
# </ul>

# %% [markdown]
# Exercise
# -------------------
# 1. Use ```CountVectorizer``` / ```TfidfVectorizer``` to fit the collection of documents
# 2. How many unique tokens are there in text? Print some examples (ie first few hundred).
# 3. What methods you can use to reduce this number?
#    - Check out and experiment with the arguments: ```ngram_range```, ```min_df```. How the vocabulary size changes with each change?
#    - What would you replace / delete from the text?
# 4. Write a custom function `clean_text` that accepts a text as input and transforms it (remove/hash numbers, delete short/long words etc.)
# 5. (Extra points) When would you use ```HashingVectorizer```?

# %%
##########################
# put your solution here #
##########################
count_vec = CountVectorizer(analyzer='word', min_df = 1, ngram_range = (2, 3))
count_vec.fit(X).vocabulary_
# Out:
# {'hotpoint rfa52s': 488171,
#  'rfa52s rfa52t': 766232,
#  'rfa52t rfaa52': 766234,
#  'rfaa52 fridge': 766236,
#  'fridge freezer': 415867,
#  'freezer top': 415239,
#  'top middle': 924224,
#  'middle bottom': 606319,
#  'bottom drawer': 199394,
#  'drawer front': 337902,
#  'front flap': 417432,
#  'hotpoint rfa52s rfa52t': 488172,
#  'rfa52s rfa52t rfaa52': 766233,
#  'rfa52t rfaa52 fridge': 766235,
#  'rfaa52 fridge freezer': 766237,
#  'fridge freezer top': 415918,
#  'freezer top middle': 415240,
#  'top middle bottom': 924225,
#  'middle bottom drawer': 606320,
#  'bottom drawer front': 199396,
#  'drawer front flap': 337905,
#  'wonderland new': 1006347,
#  'new dvd': 640222,
#  'wonderland new dvd': 1006348,
#  'new ladies': 641700,
#  'ladies womens': 542191,
#  'womens designer': 1004285,
#  'designer style': 321054,
#  'style leather': 881394,
#  'leather tote': 552752,
#  'tote shopper': 926572,
#  'shopper bag': 821271,
#  'bag celebrity': 152054,
#  'celebrity handbag': 246609,
#  'new ladies womens': 641840,
#  'ladies womens designer': 542237,
#  'womens designer style': 1004292,
#  'designer style leather': 321057,
#  'style leather tote': 881396,
#  'leather tote shopper': 552755,
#  'tote shopper bag': 926573,
#  'shopper bag celebrity': 821273,
#  'bag celebrity handbag': 152055,
#  '1x ngk': 39188,
#  'ngk copper': 645964,
#  'copper core': 285658,
#  'core spark': 286833,
#  'spark plug': 853045,
#  'plug bkr6ez': 714028,
#  'bkr6ez 4619': 176698,
#  '1x ngk copper': 39189,
#  'ngk copper core': 645965,
#  'copper core spark': 285661,
#  'core spark plug': 286834,
#  'spark plug bkr6ez': 853106,
#  'plug bkr6ez 4619': 714029,
#  'floral butterflies': 398140,
#  'butterflies fashion': 220081,
#  'fashion case': 378056,
#  'case for': 240630,
#  'for galaxy': 406481,
#  'galaxy s4': 424586,
#  's4 i9500': 785259,
#  'i9500 slip': 493688,
#  'slip pouch': 841534,
#  'pouch cover': 723124,
#  'floral butterflies fashion': 398143,
#  'butterflies fashion case': 220082,
#  'fashion case for': 378058,
#  'case for galaxy': 240654,
#  'for galaxy s4': 406493,
#  'galaxy s4 i9500': 424599,
#  's4 i9500 slip': 785272,
#  'i9500 slip pouch': 493689,
#  'slip pouch cover': 841535,
#  'crummy cookie': 299160,
#  'cookie trick': 284800,
#  'trick deluxe': 935665,
#  'deluxe edition': 318136,
#  'edition sensational': 354404,
#  'sensational street': 804310,
#  'street magic': 876174,
#  'magic tricks': 581863,
#  'crummy cookie trick': 299161,
#  'cookie trick deluxe': 284801,
#  'trick deluxe edition': 935666,
#  'deluxe edition sensational': 318140,
#  'edition sensational street': 354405,
#  'sensational street magic': 804311,
#  'street magic tricks': 876176,
#  'london wall': 570340,
#  'wall clock': 974843,
#  'clock new': 267970,
#  'new boxed': 639397,
#  'boxed 17cm': 201577,
#  '17cm england': 30555,
#  'england souvenir': 363092,
#  'souvenir tourist': 851715,
#  'tourist sights': 927484,
#  'sights great': 825131,
#  'great britain': 449378,
#  'london wall clock': 570341,
#  'wall clock new': 974871,
#  'clock new boxed': 267971,
#  'new boxed 17cm': 639398,
#  'boxed 17cm england': 201578,
#  '17cm england souvenir': 30556,
#  'england souvenir tourist': 363095,
#  'souvenir tourist sights': 851716,
#  'tourist sights great': 927486,
#  'sights great britain': 825132,
#  'lamborghini reventon': 543024,
#  'reventon radio': 765528,
#  'radio control': 747353,
#  'control car': 283145,
#  'car 18': 234249,
#  '18 electric': 31033,
#  'electric rc': 357155,
#  'rc remote': 751407,
#  'remote car': 760252,
#  'car kids': 234966,
#  'kids boys': 526683,
#  'boys toy': 203623,
#  'lamborghini reventon radio': 543025,
#  'reventon radio control': 765529,
#  'radio control car': 747355,
#  'control car 18': 283147,
#  'car 18 electric': 234250,
#  '18 electric rc': 31035,
#  'electric rc remote': 357156,
#  'rc remote car': 751408,
#  'remote car kids': 760253,
#  'car kids boys': 234967,
#  'kids boys toy': 526704,
#  '50 round': 78477,
#  'round wooden': 778274,
#  'wooden lolly': 1007084,
#  'lolly lollipop': 569917,
#  'lollipop sticks': 569898,
#  'sticks food': 871527,
#  'food craft': 403015,
#  'craft use': 294866,
#  'use 89mm': 954701,
#  '89mm 4mm': 101694,
#  '50 round wooden': 78478,
#  'round wooden lolly': 778277,
#  'wooden lolly lollipop': 1007085,
#  'lolly lollipop sticks': 569919,
#  'lollipop sticks food': 569902,
#  'sticks food craft': 871528,
#  'food craft use': 403016,
#  'craft use 89mm': 294869,
#  'use 89mm 4mm': 954702,
#  'set of': 809285,
#  'of 13ft': 656406,
#  '13ft 4lb': 23086,
#  '4lb test': 76229,
#  'test curve': 906580,
#  'curve carp': 303150,
#  'carp rods': 238745,
#  'rods hi': 773905,
#  'hi quality': 476640,
#  'quality from': 742191,
#  'from alcedo': 416747,
#  'alcedo 55mm': 122537,
#  '55mm butt': 83167,
#  'butt ring': 219973,
#  'set of 13ft': 809291,
#  'of 13ft 4lb': 656407,
#  '13ft 4lb test': 23087,
#  '4lb test curve': 76230,
#  'test curve carp': 906581,
#  'curve carp rods': 303151,
#  'carp rods hi': 238747,
#  'rods hi quality': 773906,
#  'hi quality from': 476641,
#  'quality from alcedo': 742192,
#  'from alcedo 55mm': 416748,
#  'alcedo 55mm butt': 122538,
#  '55mm butt ring': 83168,
#  'new adidas': 638705,
#  'adidas originals': 116792,
#  'originals womens': 671356,
#  'womens firebird': 1004425,
#  'firebird blue': 388407,
#  'blue zip': 189921,
#  'zip track': 1023848,
#  'track top': 929587,
#  'top all': 923407,
#  'all sizes': 123609,
#  'new adidas originals': 638719,
#  'adidas originals womens': 116822,
#  'originals womens firebird': 671359,
#  'womens firebird blue': 1004426,
#  'firebird blue zip': 388408,
#  'blue zip track': 189922,
#  'zip track top': 1023849,
#  'track top all': 929588,
#  'top all sizes': 923409,
#  'black leather': 179946,
#  'leather belt': 551025,
#  'belt pouch': 169345,
#  'pouch double': 723138,
#  'double zipped': 336171,
#  'zipped pockets': 1024004,
#  'pockets front': 717194,
#  'front pouch': 417829,
#  'pouch tt599': 723330,
#  'black leather belt': 179959,
#  'leather belt pouch': 551049,
#  'belt pouch double': 169346,
#  'pouch double zipped': 723139,
#  'double zipped pockets': 336172,
#  'zipped pockets front': 1024005,
#  'pockets front pouch': 717195,
#  'front pouch tt599': 417830,
#  'front brake': 417170,
#  'brake lever': 205996,
#  'lever kawasaki': 558024,
#  'kawasaki kx': 523296,
#  'kx 250': 535787,
#  '250 kx': 52677,
#  '250 2000': 52487,
#  '2000 08': 40784,
#  '08 new': 6170,
#  'front brake lever': 417181,
#  'brake lever kawasaki': 206040,
#  'lever kawasaki kx': 558026,
#  'kawasaki kx 250': 523298,
#  'kx 250 kx': 535793,
#  '250 kx 250': 52678,
#  'kx 250 2000': 535791,
#  '250 2000 08': 52488,
#  '2000 08 new': 40786,
#  'cnc router': 270084,
#  'router bit': 778406,
#  'bit 0mm': 176216,
#  '0mm safe': 7249,
#  'safe end': 787351,
#  'end carbide': 361319,
#  'carbide cutter': 236347,
#  'cnc router bit': 270085,
#  'router bit 0mm': 778407,
#  'bit 0mm safe': 176217,
#  '0mm safe end': 7250,
#  'safe end carbide': 787352,
#  'end carbide cutter': 361320,
#  'photo booth': 700967,
#  'booth props': 196941,
#  'props for': 733139,
#  'for birthday': 405094,
#  'birthday hen': 175821,
#  'hen or': 474935,
#  'or wedding': 668930,
#  'wedding party': 983678,
#  'party fun': 687558,
#  'fun 10': 420605,
#  '10 card': 8275,
#  'card accessories': 236894,
#  'photo booth props': 700968,
#  'booth props for': 196942,
#  'props for birthday': 733140,
#  'for birthday hen': 405095,
#  'birthday hen or': 175822,
#  'hen or wedding': 474936,
#  'or wedding party': 668931,
#  'wedding party fun': 983699,
#  'party fun 10': 687559,
#  'fun 10 card': 420606,
#  '10 card accessories': 8276,
#  'children canvas': 254646,
#  'canvas shoes': 232216,
#  'children canvas shoes': 254647,
#  'blue matt': 188407,
#  'matt vehicle': 590283,
#  'vehicle wrap': 961440,
#  'wrap vinyl': 1010004,
#  'vinyl 5m': 966974,
#  '5m x1': 85892,
#  'x1 5m': 1011257,
#  '5m air': 85605,
#  'blue matt vehicle': 188409,
#  'matt vehicle wrap': 590284,
#  'vehicle wrap vinyl': 961444,
#  'wrap vinyl 5m': 1010009,
#  'vinyl 5m x1': 966975,
#  '5m x1 5m': 85893,
#  'x1 5m air': 1011258,
#  'weight watchers': 984691,
#  'watchers easy': 979599,
#  'easy analysis': 352241,
#  'analysis body': 127788,
#  'body fat': 193034,
#  'fat scale': 379134,
#  'scale 8981u': 793898,
#  'weight watchers easy': 984692,
#  'watchers easy analysis': 979600,
#  'easy analysis body': 352242,
#  'analysis body fat': 127789,
#  'body fat scale': 193037,
#  'fat scale 8981u': 379135,
#  '41101 rc': 71388,
#  'rc 10': 751123,
#  '10 scale': 9443,
#  'scale truggy': 794135,
#  'truggy truck': 938799,
#  'truck body': 938485,
#  'body shell': 193267,
#  'shell cover': 815569,
#  'cover blue': 291540,
#  'blue cut': 187538,
#  '41101 rc 10': 71389,
#  'rc 10 scale': 751129,
#  '10 scale truggy': 9463,
#  'scale truggy truck': 794137,
#  'truggy truck body': 938800,
#  'truck body shell': 938486,
#  'body shell cover': 193274,
#  'shell cover blue': 815571,
#  'cover blue cut': 291543,
#  'pack of': 677761,
#  'of 25': 656514,
#  '25 brand': 52002,
#  'brand new': 206485,
#  'new connector': 639908,
#  'connector plugs': 282106,
#  'plugs twist': 715532,
#  'twist on': 943904,
#  'on type': 664629,
#  'pack of 25': 677780,
#  'of 25 brand': 656520,
#  '25 brand new': 52003,
#  'brand new connector': 206623,
#  'new connector plugs': 639909,
#  'connector plugs twist': 282108,
#  'plugs twist on': 715533,
#  'twist on type': 943906,
#  'hk1712 budget': 479962,
#  'budget drawn': 215402,
#  'drawn cup': 338067,
#  'cup needle': 301864,
#  'needle roller': 636384,
#  'roller bearing': 774453,
#  'bearing open': 165255,
#  'open end': 666736,
#  'end 17x23x12mm': 361246,
#  'hk1712 budget drawn': 479963,
#  'budget drawn cup': 215403,
#  'drawn cup needle': 338068,
#  'cup needle roller': 301865,
#  'needle roller bearing': 636385,
#  'roller bearing open': 774462,
#  'bearing open end': 165256,
#  'open end 17x23x12mm': 666737,
#  'retro gadgets': 764563,
#  'gadgets steampunk': 423858,
#  'steampunk case': 867397,
#  'for iphone': 407126,
#  'retro gadgets steampunk': 764565,
#  'gadgets steampunk case': 423859,
#  'steampunk case for': 867398,
#  'case for iphone': 240665,
#  'golf pride': 446113,
#  'pride multicompound': 727619,
#  'multicompound platinum': 628540,
#  'platinum mens': 712458,
#  'mens std': 599278,
#  'std grips': 867166,
#  'grips scarlet': 454095,
#  'scarlet red': 794716,
#  'red platinum': 756646,
#  'golf pride multicompound': 446116,
#  'pride multicompound platinum': 727620,
#  'multicompound platinum mens': 628541,
#  'platinum mens std': 712459,
#  'mens std grips': 599279,
#  'std grips scarlet': 867167,
#  'grips scarlet red': 454096,
#  'scarlet red platinum': 794718,
#  '10 butterfly': 8242,
#  'butterfly place': 220403,
#  'place cards': 708781,
#  'cards for': 237798,
#  'for use': 410213,
#  'use with': 954826,
#  'with wedding': 1001646,
#  'wedding wine': 983937,
#  'wine champagne': 994826,
#  'champagne glasses': 249658,
#  'glasses engagement': 439544,
#  '10 butterfly place': 8243,
#  'butterfly place cards': 220404,
#  'place cards for': 708782,
#  'cards for use': 237802,
#  'for use with': 410218,
#  'use with wedding': 954846,
#  'with wedding wine': 1001647,
#  'wedding wine champagne': 983938,
#  'wine champagne glasses': 994828,
#  'champagne glasses engagement': 249659,
#  'seat leon': 802013,
#  'leon 20v': 556933,
#  '20v 1999': 47798,
#  '1999 2006': 37143,
#  '2006 mass': 43512,
#  'mass air': 588513,
#  'air flow': 120650,
#  'flow meter': 399146,
#  'meter sensor': 603238,
#  'sensor maf': 804733,
#  'maf 06a906461a': 581372,
#  'seat leon 20v': 802026,
#  'leon 20v 1999': 556934,
#  '20v 1999 2006': 47799,
#  '1999 2006 mass': 37149,
#  '2006 mass air': 43513,
#  'mass air flow': 588514,
#  'air flow meter': 120653,
#  'flow meter sensor': 399159,
#  'meter sensor maf': 603259,
#  'sensor maf 06a906461a': 804736,
#  'genuine dyson': 431307,
#  'dyson dc04': 348410,
#  'dc04 dc07': 312569,
#  'dc07 dc14': 312695,
#  'dc14 dc33': 312862,
#  'dc33 vacuum': 313197,
#  'vacuum cleaner': 956824,
#  'cleaner clutch': 264874,
#  'clutch assembly': 269363,
#  'assembly with': 141644,
#  'with belts': 998012,
#  'genuine dyson dc04': 431314,
#  'dyson dc04 dc07': 348413,
#  'dc04 dc07 dc14': 312572,
#  'dc07 dc14 dc33': 312701,
#  'dc14 dc33 vacuum': 312867,
#  'dc33 vacuum cleaner': 313198,
#  'vacuum cleaner clutch': 956859,
#  'cleaner clutch assembly': 264875,
#  'clutch assembly with': 269364,
#  'assembly with belts': 141645,
#  'asos lace': 140849,
#  'lace vest': 538227,
#  'vest top': 963670,
#  'top in': 924035,
#  'in orange': 499017,
#  'orange bnwt': 669173,
#  'bnwt ee93': 191591,
#  'asos lace vest': 140851,
#  'lace vest top': 538228,
#  'vest top in': 963688,
#  'top in orange': 924047,
#  'in orange bnwt': 499018,
#  'orange bnwt ee93': 669174,
#  '1d one': 37734,
#  'one direction': 664968,
#  'direction advent': 327868,
#  'advent calendar': 118301,
#  'calendar milk': 228064,
#  'milk chocolate': 607500,
#  '1d one direction': 37735,
#  'one direction advent': 664972,
#  'direction advent calendar': 327869,
#  'advent calendar milk': 118305,
#  'calendar milk chocolate': 228065,
#  'primigi girls': 727975,
#  'girls domin': 436979,
#  'domin white': 333530,
#  'white and': 987925,
#  'and silver': 130383,
#  'silver leather': 828893,
#  'leather sandals': 552312,
#  'sandals velcro': 790893,
#  'velcro straps': 961730,
#  'straps 41': 875629,
#  '41 46': 71261,
#  '46 00': 73878,
#  'primigi girls domin': 727976,
#  'girls domin white': 436980,
#  'domin white and': 333531,
#  'white and silver': 987933,
#  'and silver leather': 130388,
#  'silver leather sandals': 828899,
#  'leather sandals velcro': 552317,
#  'sandals velcro straps': 790896,
#  'velcro straps 41': 961733,
#  'straps 41 46': 875630,
#  '41 46 00': 71262,
#  'jomanda sleepey': 518734,
#  'sleepey sheepey': 838312,
#  'jomanda sleepey sheepey': 518735,
#  'signed preiss': 825917,
#  'preiss solid': 725922,
#  'solid real': 849549,
#  'real bronze': 752495,
#  'bronze sculpture': 211117,
#  'sculpture erotic': 799378,
#  'erotic female': 365074,
#  'female no': 381602,
#  'no reserve': 648903,
#  'reserve statue': 763097,
#  'statue decor': 866900,
#  'signed preiss solid': 825918,
#  'preiss solid real': 725923,
#  'solid real bronze': 849550,
#  'real bronze sculpture': 752497,
#  'bronze sculpture erotic': 211132,
#  'sculpture erotic female': 799379,
#  'erotic female no': 365075,
#  'female no reserve': 381603,
#  'no reserve statue': 648904,
#  'reserve statue decor': 763098,
#  'silicon case': 826291,
#  'for itouch': 407198,
#  'itouch itouch': 510692,
#  'itouch black': 510689,
#  'silicon case for': 826293,
#  'case for itouch': 240667,
#  'for itouch itouch': 407201,
#  'itouch itouch black': 510693,
#  '10 notebook': 9083,
#  'notebook laptop': 650829,
#  'laptop dc': 544954,
#  'dc jack': 312301,
#  'jack power': 512011,
#  'power socket': 724353,
#  'socket connector': 846834,
#  'connector for': 281998,
#  'for fujitsu': 406461,
#  'fujitsu c2240': 419797,
#  'c2240 5mm': 223234,
#  '10 notebook laptop': 9084,
#  'notebook laptop dc': 650834,
#  'laptop dc jack': 544955,
#  'dc jack power': 312308,
#  'jack power socket': 512016,
#  'power socket connector': 724356,
#  'socket connector for': 846849,
#  'connector for fujitsu': 282003,
#  'for fujitsu c2240': 406462,
#  'fujitsu c2240 5mm': 419798,
#  'sterling silver': 869760,
#  'silver real': 829490,
#  'real black': 752482,
#  'black australian': 177399,
#  'australian opal': 145046,
#  'opal matrix': 666327,
#  'matrix pendant': 589975,
#  'pendant 925': 695215,
#  '925 jewelry': 105226,
#  'jewelry birthstone': 516824,
#  'sterling silver real': 869992,
#  'silver real black': 829491,
#  'real black australian': 752483,
#  'black australian opal': 177401,
#  'australian opal matrix': 145047,
#  'opal matrix pendant': 666328,
#  'matrix pendant 925': 589976,
#  'pendant 925 jewelry': 695218,
#  '925 jewelry birthstone': 105227,
#  'diamond halo': 324259,
#  'halo earrings': 461291,
#  'earrings 80cts': 351504,
#  '80cts si1': 99115,
#  'si1 colour': 823732,
#  'colour 18': 274818,
#  '18 carat': 30953,
#  'carat white': 236067,
#  'white gold': 989165,
#  'gold new': 444398,
#  'new hallmarked': 641152,
#  'diamond halo earrings': 324261,
#  'halo earrings 80cts': 461292,
#  'earrings 80cts si1': 351505,
#  '80cts si1 colour': 99116,
#  'si1 colour 18': 823733,
#  'colour 18 carat': 274819,
#  '18 carat white': 30955,
#  'carat white gold': 236069,
#  'white gold new': 989337,
#  'gold new hallmarked': 444405,
#  'ngk ignition': 645992,
#  'ignition coil': 495511,
#  'coil pack': 272176,
#  'pack renault': 678107,
#  'renault clio': 760969,
#  'clio mk': 266810,
#  'mk sport': 612673,
#  'sport tourer': 858115,
#  'tourer tce': 927345,
#  'tce 100': 901785,
#  '100 2008': 9980,
#  '2008 09': 44076,
#  'ngk ignition coil': 645993,
#  'ignition coil pack': 495533,
#  'coil pack renault': 272213,
#  'pack renault clio': 678109,
#  'renault clio mk': 761012,
#  'clio mk sport': 266815,
#  'mk sport tourer': 612674,
#  'sport tourer tce': 858118,
#  'tourer tce 100': 927346,
#  'tce 100 2008': 901786,
#  '100 2008 09': 9981,
#  '3m clear': 68340,
#  'clear paint': 265946,
#  'paint protection': 681090,
#  'protection helicopter': 733416,
#  'helicopter bike': 474005,
#  'bike frame': 173298,
#  'frame paint': 413896,
#  'paint protector': 681094,
#  '3m clear paint': 68342,
#  'clear paint protection': 265947,
#  'paint protection helicopter': 681092,
#  'protection helicopter bike': 733417,
#  'helicopter bike frame': 474006,
#  'bike frame paint': 173300,
#  'frame paint protector': 413897,
#  '20 black': 39652,
#  'black rondelle': 181453,
#  'rondelle crystal': 775426,
#  'crystal glass': 299729,
#  'glass beads': 438675,
#  'beads 10x10x8mm': 163892,
#  '10x10x8mm 182': 15246,
#  '20 black rondelle': 39657,
#  'black rondelle crystal': 181454,
#  'rondelle crystal glass': 775427,
#  'crystal glass beads': 299730,
#  'glass beads 10x10x8mm': 438676,
#  'beads 10x10x8mm 182': 163893,
#  'buy any': 221109,
#  'any designer': 134260,
#  'designer styled': 321060,
#  'styled black': 882146,
#  'black bodystockings': 177681,
#  'bodystockings save': 193728,
#  'save choices': 793210,
#  'choices multi': 256526,
#  'multi buy': 627727,
#  'buy offer': 221138,
#  'buy any designer': 221110,
#  'any designer styled': 134261,
#  'designer styled black': 321061,
#  'styled black bodystockings': 882147,
#  'black bodystockings save': 177682,
#  'bodystockings save choices': 193729,
#  'save choices multi': 793211,
#  'choices multi buy': 256527,
#  'multi buy offer': 627729,
#  'popular logo': 720646,
#  'logo collection': 569527,
#  'collection vol': 274014,
#  'vol 11': 969269,
#  '11 tattoo': 15824,
#  'tattoo designs': 901040,
#  'designs outline': 321290,
#  'outline stencil': 673625,
#  'stencil book': 869289,
#  'popular logo collection': 720647,
#  'logo collection vol': 569528,
#  'collection vol 11': 274015,
#  'vol 11 tattoo': 969270,
#  '11 tattoo designs': 15825,
#  'tattoo designs outline': 901041,
#  'designs outline stencil': 321291,
#  'outline stencil book': 673626,
#  'mikki walkrite': 606965,
#  'walkrite anti': 974708,
#  'anti pull': 133673,
#  'pull non': 735713,
#  'non pull': 649660,
#  'pull harness': 735690,
#  'harness for': 465770,
#  'for dogs': 406040,
#  'dogs large': 332981,
#  'mikki walkrite anti': 606966,
#  'walkrite anti pull': 974709,
#  'anti pull non': 133674,
#  'pull non pull': 735714,
#  'non pull harness': 649661,
#  'pull harness for': 735691,
#  'harness for dogs': 465771,
#  'for dogs large': 406046,
#  '1200 round': 19304,
#  'round shaped': 778136,
#  'shaped rhinestone': 813645,
#  'rhinestone 5mm': 766571,
#  '1200 round shaped': 19305,
#  'round shaped rhinestone': 778139,
#  'shaped rhinestone 5mm': 813646,
#  'fast powerful': 378780,
#  'powerful intel': 724777,
#  'intel desktop': 505609,
#  'desktop gaming': 321643,
#  'gaming gamer': 425420,
#  'gamer pc': 425291,
#  'pc gt': 691558,
#  'gt 740': 455824,
#  '740 16gb': 95604,
#  '16gb 2tb': 29003,
#  '2tb 60gb': 57834,
#  '60gb ssd': 88926,
#  'ssd 142377': 861942,
#  'fast powerful intel': 378782,
#  'powerful intel desktop': 724779,
#  'intel desktop gaming': 505610,
#  'desktop gaming gamer': 321644,
#  'gaming gamer pc': 425421,
#  'gamer pc gt': 425292,
#  'pc gt 740': 691561,
#  'gt 740 16gb': 455825,
#  '740 16gb 2tb': 95608,
#  '16gb 2tb 60gb': 29006,
#  '2tb 60gb ssd': 57835,
#  '60gb ssd 142377': 88946,
#  'am tech': 125921,
#  'tech mini': 903997,
#  'mini top': 609511,
#  'top end': 923820,
#  'end cutter': 361346,
#  'cutter precision': 305115,
#  'precision pliers': 725767,
#  'pliers craft': 713497,
#  'craft modeling': 294758,
#  'modeling wire': 616177,
#  'wire work': 996789,
#  'work b3185': 1008110,
#  'am tech mini': 125938,
#  'tech mini top': 903998,
#  'mini top end': 609513,
#  'top end cutter': 923821,
#  'end cutter precision': 361347,
#  'cutter precision pliers': 305116,
#  'precision pliers craft': 725768,
#  'pliers craft modeling': 713498,
#  'craft modeling wire': 294759,
#  'modeling wire work': 616178,
#  'wire work b3185': 996790,
#  'bourjois paris': 199778,
#  'paris khol': 686058,
#  'khol contour': 526089,
#  'contour shadow': 282897,
#  'shadow light': 812565,
#  'light eye': 560941,
#  'eye pencil': 372153,
#  'pencil eyeliner': 694887,
#  'eyeliner 16': 372480,
#  '16 hour': 27864,
#  'bourjois paris khol': 199784,
#  'paris khol contour': 686059,
#  'khol contour shadow': 526090,
#  'contour shadow light': 282898,
#  'shadow light eye': 812566,
#  'light eye pencil': 560942,
#  'eye pencil eyeliner': 372157,
#  'pencil eyeliner 16': 694888,
#  'eyeliner 16 hour': 372481,
#  'genuine hotpoint': 431665,
#  'hotpoint ctd00g': 488070,
#  'ctd00g ctd80p': 300735,
#  'ctd80p tdc30s': 300741,
#  'tdc30s tumble': 902188,
#  'tumble dryer': 940775,
#  'dryer fan': 343087,
#  'fan motor': 376939,
#  'motor cooling': 621536,
#  'cooling impellor': 285314,
#  'genuine hotpoint ctd00g': 431677,
#  'hotpoint ctd00g ctd80p': 488071,
#  'ctd00g ctd80p tdc30s': 300736,
#  'ctd80p tdc30s tumble': 300742,
#  'tdc30s tumble dryer': 902189,
#  'tumble dryer fan': 940795,
#  'dryer fan motor': 343089,
#  'fan motor cooling': 376949,
#  'motor cooling impellor': 621537,
#  'fiore alexandra': 388047,
#  'alexandra patterned': 122711,
#  'patterned tights': 690444,
#  'tights 60': 915046,
#  '60 denier': 87656,
#  'denier slight': 318551,
#  'slight sheen': 840528,
#  'sheen rose': 814627,
#  'rose pattern': 776450,
#  'pattern pair': 690237,
#  'fiore alexandra patterned': 388048,
#  'alexandra patterned tights': 122712,
#  'patterned tights 60': 690447,
#  'tights 60 denier': 915047,
#  '60 denier slight': 87658,
#  'denier slight sheen': 318552,
#  'slight sheen rose': 840529,
#  'sheen rose pattern': 814628,
#  'rose pattern pair': 776453,
#  'plain black': 708936,
#  'black hoodie': 179548,
#  'hoodie hoody': 484850,
#  'hoody unisex': 485204,
#  'unisex hooded': 949395,
#  'hooded top': 484695,
#  'top jumper': 924073,
#  'jumper pullover': 520192,
#  'pullover sweater': 736096,
#  'sweater winter': 890770,
#  'winter gift': 995530,
#  'plain black hoodie': 708944,
#  'black hoodie hoody': 179551,
#  'hoodie hoody unisex': 484860,
#  'hoody unisex hooded': 485205,
#  'unisex hooded top': 949397,
#  'hooded top jumper': 484702,
#  'top jumper pullover': 924081,
#  'jumper pullover sweater': 520194,
#  'pullover sweater winter': 736101,
#  'sweater winter gift': 890771,
#  'womens paisley': 1005383,
#  'paisley print': 682441,
#  'print ladies': 728954,
#  'ladies off': 540729,
#  'off shoulder': 659740,
#  'shoulder turn': 822918,
#  'turn up': 942022,
#  'up sleeve': 952194,
#  'sleeve lace': 838846,
#  'lace trim': 538082,
#  'trim top': 936315,
#  'top plus': 924383,
#  'plus size': 716176,
#  'womens paisley print': 1005384,
#  'paisley print ladies': 682447,
#  'print ladies off': 728963,
#  'ladies off shoulder': 540730,
#  'off shoulder turn': 659750,
#  'shoulder turn up': 822919,
#  'turn up sleeve': 942037,
#  'up sleeve lace': 952198,
#  'sleeve lace trim': 838848,
#  'lace trim top': 538097,
#  'trim top plus': 936316,
#  'top plus size': 924384,
#  'me to': 592608,
#  'to you': 920107,
#  'you tatty': 1020319,
#  'tatty teddy': 901220,
#  'teddy take': 904470,
#  'take apart': 898236,
#  'apart kids': 134487,
#  'kids childrens': 526784,
#  'childrens baking': 254927,
#  'baking cooking': 154163,
#  'cooking gift': 284835,
#  'gift set': 435060,
#  'me to you': 592609,
#  'to you tatty': 920114,
#  'you tatty teddy': 1020320,
#  'tatty teddy take': 901230,
#  'teddy take apart': 904471,
#  'take apart kids': 898237,
#  'apart kids childrens': 134488,
#  'kids childrens baking': 526786,
#  'childrens baking cooking': 254929,
#  'baking cooking gift': 154164,
#  'cooking gift set': 284836,
#  '511 tactical': 81025,
#  'tactical recoil': 897325,
#  'recoil dobby': 754428,
#  'dobby cap': 331849,
#  'cap black': 232523,
#  'black headwear': 179468,
#  'headwear all': 470865,
#  '511 tactical recoil': 81040,
#  'tactical recoil dobby': 897326,
#  'recoil dobby cap': 754429,
#  'dobby cap black': 331850,
#  'cap black headwear': 232534,
#  'black headwear all': 179469,
#  'headwear all sizes': 470866,
#  'ladies patent': 540820,
#  'patent snake': 689641,
#  'snake skin': 845115,
#  'skin print': 835848,
#  'print shoulder': 729326,
#  'shoulder bag': 822621,
#  'bag available': 151865,
#  'available in': 146233,
#  'in different': 498292,
#  'different colours': 326122,
#  'ladies patent snake': 540824,
#  'patent snake skin': 689642,
#  'snake skin print': 845120,
#  'skin print shoulder': 835851,
#  'print shoulder bag': 729327,
#  'shoulder bag available': 822627,
#  'bag available in': 151866,
#  'available in different': 146246,
#  'in different colours': 498293,
#  'system 3083': 894113,
#  '3083 internal': 60431,
#  'internal speakers': 506347,
#  'speakers cover': 854138,
#  'cover 253': 291301,
#  'system 3083 internal': 894114,
#  '3083 internal speakers': 60432,
#  'internal speakers cover': 506357,
#  'speakers cover 253': 854139,
#  'rug runner': 782284,
#  'runner traditional': 782980,
#  'traditional agra': 930013,
#  'agra hand': 119911,
#  'hand woven': 462608,
#  'woven camel': 1009315,
#  'camel gold': 228945,
#  'gold small': 444992,
#  'small medium': 842985,
#  'medium large': 593765,
#  'rug runner traditional': 782286,
#  'runner traditional agra': 782981,
#  'traditional agra hand': 930014,
#  'agra hand woven': 119912,
#  'hand woven camel': 462610,
#  'woven camel gold': 1009316,
#  'camel gold small': 228946,
#  'gold small medium': 444995,
#  'small medium large': 842993,
#  'genuine delonghi': 431237,
#  'delonghi caple': 317859,
#  'caple cda': 233581,
#  'cda cd200': 245693,
#  'cd200 2ss': 245661,
#  '2ss grill': 57789,
#  'grill pan': 453296,
#  'pan handle': 683114,
#  'handle 037144': 462959,
#  'genuine delonghi caple': 431238,
#  'delonghi caple cda': 317860,
#  'caple cda cd200': 233582,
#  'cda cd200 2ss': 245694,
#  'cd200 2ss grill': 245662,
#  '2ss grill pan': 57790,
#  'grill pan handle': 453298,
#  'pan handle 037144': 683115,
#  'hp nx9000': 489658,
#  'nx9000 hdd': 654334,
#  'hdd hard': 468442,
#  'hard drive': 465042,
#  'drive disk': 341280,
#  'disk caddy': 329365,
#  'caddy 312': 227081,
#  'hp nx9000 hdd': 489659,
#  'nx9000 hdd hard': 654335,
#  'hdd hard drive': 468445,
#  'hard drive disk': 465065,
#  'drive disk caddy': 341281,
#  'disk caddy 312': 329369,
#  'boombox mini': 196221,
#  'mini speaker': 609400,
#  'speaker microphone': 853989,
#  'microphone for': 605754,
#  'for samsung': 409153,
#  'samsung galaxy': 789511,
#  'galaxy s2': 424549,
#  's2 s3': 784630,
#  's3 s4': 784999,
#  's4 s5': 785353,
#  's5 note': 785660,
#  'note red': 650696,
#  'boombox mini speaker': 196222,
#  'mini speaker microphone': 609403,
#  'speaker microphone for': 853990,
#  'microphone for samsung': 605762,
#  'for samsung galaxy': 409176,
#  'samsung galaxy s2': 789557,
#  'galaxy s2 s3': 424558,
#  's2 s3 s4': 784633,
#  's3 s4 s5': 785004,
#  's4 s5 note': 785357,
#  's5 note red': 785661,
#  'esp oval': 365740,
#  'oval rig': 673961,
#  'rig rings': 768475,
#  'rings 5mm': 770509,
#  '5mm carp': 86114,
#  'carp fishing': 238638,
#  'esp oval rig': 365741,
#  'oval rig rings': 673962,
#  'rig rings 5mm': 768476,
#  'rings 5mm carp': 770511,
#  '5mm carp fishing': 86116,
#  '80gb external': 99146,
#  'external usb': 371136,
#  'usb ultra': 954604,
#  'ultra slim': 947501,
#  'slim pocket': 840904,
#  'pocket drive': 716852,
#  'drive brand': 341220,
#  '80gb external usb': 99148,
#  ...}

# %%
count_vec = CountVectorizer()
len(count_vec.fit(X).vocabulary_)
# Out:
# 76349

# %%
count_vec = CountVectorizer(min_df = 50, ngram_range = (1, 1))
len(count_vec.fit(X).vocabulary_)
# Out:
# 3012

# %%
tfidf = TfidfVectorizer()
tfidf.fit(X).vocabulary_
# Out:
# {'hotpoint': 40779,
#  'rfa52s': 59074,
#  'rfa52t': 59075,
#  'rfaa52': 59076,
#  'fridge': 36292,
#  'freezer': 36247,
#  'top': 68943,
#  'middle': 49359,
#  'bottom': 22131,
#  'drawer': 30608,
#  'front': 36347,
#  'flap': 35475,
#  'wonderland': 74053,
#  'new': 51728,
#  'dvd': 31164,
#  'ladies': 45340,
#  'womens': 74045,
#  'designer': 29443,
#  'style': 65872,
#  'leather': 45800,
#  'tote': 69030,
#  'shopper': 62659,
#  'bag': 19780,
#  'celebrity': 24944,
#  'handbag': 39383,
#  '1x': 4960,
#  'ngk': 51788,
#  'copper': 26960,
#  'core': 26990,
#  'spark': 64295,
#  'plug': 55542,
#  'bkr6ez': 21427,
#  '4619': 9745,
#  'floral': 35642,
#  'butterflies': 23238,
#  'fashion': 34585,
#  'case': 24506,
#  'for': 35919,
#  'galaxy': 37059,
#  's4': 60581,
#  'i9500': 41371,
#  'slip': 63506,
#  'pouch': 55933,
#  'cover': 27215,
#  'crummy': 27662,
#  'cookie': 26908,
#  'trick': 69467,
#  'deluxe': 29311,
#  'edition': 32021,
#  'sensational': 62028,
#  'street': 65715,
#  'magic': 47786,
#  'tricks': 69470,
#  'london': 46640,
#  'wall': 72902,
#  'clock': 26074,
#  'boxed': 22204,
#  '17cm': 4168,
#  'england': 32827,
#  'souvenir': 64163,
#  'tourist': 69069,
#  'sights': 62842,
#  'great': 38322,
#  'britain': 22635,
#  'lamborghini': 45402,
#  'reventon': 59007,
#  'radio': 57932,
#  'control': 26865,
#  'car': 24295,
#  '18': 4194,
#  'electric': 32356,
#  'rc': 58247,
#  'remote': 58777,
#  'kids': 44242,
#  'boys': 22228,
#  'toy': 69099,
#  '50': 10466,
#  'round': 59841,
#  'wooden': 74068,
#  'lolly': 46633,
#  'lollipop': 46631,
#  'sticks': 65484,
#  'food': 35877,
#  'craft': 27384,
#  'use': 71035,
#  '89mm': 14748,
#  '4mm': 10356,
#  'set': 62160,
#  'of': 52699,
#  '13ft': 3136,
#  '4lb': 10340,
#  'test': 67970,
#  'curve': 28011,
#  'carp': 24433,
#  'rods': 59641,
#  'hi': 40213,
#  'quality': 57347,
#  'from': 36344,
#  'alcedo': 17356,
#  '55mm': 11272,
#  'butt': 23232,
#  'ring': 59297,
#  'adidas': 16737,
#  'originals': 53107,
#  'firebird': 35287,
#  'blue': 21690,
#  'zip': 76067,
#  'track': 69203,
#  'all': 17446,
#  'sizes': 63091,
#  'black': 21469,
#  'belt': 20872,
#  'double': 30363,
#  'zipped': 76072,
#  'pockets': 55628,
#  'tt599': 69791,
#  'brake': 22401,
#  'lever': 46008,
#  'kawasaki': 43850,
#  'kx': 44892,
#  '250': 6061,
#  '2000': 5002,
#  '08': 1172,
#  'cnc': 26242,
#  'router': 59857,
#  'bit': 21352,
#  '0mm': 1392,
#  'safe': 60941,
#  'end': 32772,
#  'carbide': 24317,
#  'cutter': 28058,
#  'photo': 55001,
#  'booth': 22055,
#  'props': 56508,
#  'birthday': 21333,
#  'hen': 40019,
#  'or': 53034,
#  'wedding': 73273,
#  'party': 54212,
#  'fun': 36575,
#  '10': 1462,
#  'card': 24338,
#  'accessories': 16526,
#  'children': 25435,
#  'canvas': 24234,
#  'shoes': 62644,
#  'matt': 48388,
#  'vehicle': 71629,
#  'wrap': 74232,
#  'vinyl': 71961,
#  '5m': 11730,
#  'x1': 74399,
#  'air': 17089,
#  'weight': 73310,
#  'watchers': 73066,
#  'easy': 31812,
#  'analysis': 17808,
#  'body': 21865,
#  'fat': 34611,
#  'scale': 61355,
#  '8981u': 14742,
#  '41101': 9084,
#  'truggy': 69647,
#  'truck': 69629,
#  'shell': 62519,
#  'cut': 28038,
#  'pack': 53850,
#  '25': 6060,
#  'brand': 22419,
#  'connector': 26778,
#  'plugs': 55545,
#  'twist': 70086,
#  'on': 52878,
#  'type': 70173,
#  'hk1712': 40399,
#  'budget': 23010,
#  'drawn': 30612,
#  'cup': 27951,
#  'needle': 51606,
#  'roller': 59672,
#  'bearing': 20687,
#  'open': 52942,
#  '17x23x12mm': 4193,
#  'retro': 58982,
#  'gadgets': 37027,
#  'steampunk': 65383,
#  'iphone': 42277,
#  'golf': 38020,
#  'pride': 56270,
#  'multicompound': 50752,
#  'platinum': 55453,
#  'mens': 48983,
#  'std': 65367,
#  'grips': 38434,
#  'scarlet': 61402,
#  'red': 58526,
#  'butterfly': 23239,
#  'place': 55380,
#  'cards': 24362,
#  'with': 73849,
#  'wine': 73765,
#  'champagne': 25186,
#  'glasses': 37778,
#  'engagement': 32817,
#  'seat': 61859,
#  'leon': 45939,
#  '20v': 5321,
#  '1999': 4702,
#  '2006': 5044,
#  'mass': 48300,
#  'flow': 35672,
#  'meter': 49109,
#  'sensor': 62040,
#  'maf': 47765,
#  '06a906461a': 1106,
#  'genuine': 37450,
#  'dyson': 31394,
#  'dc04': 28850,
#  'dc07': 28864,
#  'dc14': 28889,
#  'dc33': 28939,
#  'vacuum': 71345,
#  'cleaner': 25940,
#  'clutch': 26157,
#  'assembly': 18719,
#  'belts': 20880,
#  'asos': 18685,
#  'lace': 45306,
#  'vest': 71779,
#  'in': 41801,
#  'orange': 53046,
#  'bnwt': 21803,
#  'ee93': 32078,
#  '1d': 4794,
#  'one': 52885,
#  'direction': 29873,
#  'advent': 16821,
#  'calendar': 24016,
#  'milk': 49436,
#  'chocolate': 25525,
#  'primigi': 56296,
#  'girls': 37689,
#  'domin': 30266,
#  'white': 73554,
#  'and': 17827,
#  'silver': 62936,
#  'sandals': 61084,
#  'velcro': 71643,
#  'straps': 65681,
#  '41': 9062,
#  '46': 9723,
#  '00': 0,
#  'jomanda': 43186,
#  'sleepey': 63429,
#  'sheepey': 62497,
#  'signed': 62857,
#  'preiss': 56176,
#  'solid': 63996,
#  'real': 58423,
#  'bronze': 22713,
#  'sculpture': 61689,
#  'erotic': 33073,
#  'female': 34947,
#  'no': 51960,
#  'reserve': 58895,
#  'statue': 65337,
#  'decor': 29169,
#  'silicon': 62916,
#  'itouch': 42488,
#  'notebook': 52090,
#  'laptop': 45507,
#  'dc': 28827,
#  'jack': 42713,
#  'power': 55958,
#  'socket': 63915,
#  'fujitsu': 36557,
#  'c2240': 23521,
#  '5mm': 11742,
#  'sterling': 65441,
#  'australian': 18996,
#  'opal': 52933,
#  'matrix': 48381,
#  'pendant': 54614,
#  '925': 15284,
#  'jewelry': 43011,
#  'birthstone': 21337,
#  'diamond': 29666,
#  'halo': 39329,
#  'earrings': 31776,
#  '80cts': 14149,
#  'si1': 62772,
#  'colour': 26481,
#  'carat': 24309,
#  'gold': 37995,
#  'hallmarked': 39320,
#  'ignition': 41591,
#  'coil': 26361,
#  'renault': 58798,
#  'clio': 26038,
#  'mk': 49677,
#  'sport': 64597,
#  'tourer': 69064,
#  'tce': 67536,
#  '100': 1463,
#  '2008': 5049,
#  '09': 1253,
#  '3m': 8717,
#  'clear': 25951,
#  'paint': 53934,
#  'protection': 56540,
#  'helicopter': 39967,
#  'bike': 21186,
#  'frame': 36146,
#  'protector': 56542,
#  '20': 5000,
#  'rondelle': 59717,
#  'crystal': 27700,
#  'glass': 37777,
#  'beads': 20657,
#  '10x10x8mm': 2055,
#  '182': 4238,
#  'buy': 23258,
#  'any': 18036,
#  'styled': 65875,
#  'bodystockings': 21881,
#  'save': 61235,
#  'choices': 25530,
#  'multi': 50736,
#  'offer': 52715,
#  'popular': 55815,
#  'logo': 46615,
#  'collection': 26422,
#  'vol': 72168,
#  '11': 2078,
#  'tattoo': 67442,
#  'designs': 29448,
#  'outline': 53282,
#  'stencil': 65418,
#  'book': 22009,
#  'mikki': 49411,
#  'walkrite': 72899,
#  'anti': 17981,
#  'pull': 56772,
#  'non': 52011,
#  'harness': 39536,
#  'dogs': 30221,
#  'large': 45515,
#  '1200': 2458,
#  'shaped': 62427,
#  'rhinestone': 59160,
#  'fast': 34592,
#  'powerful': 55979,
#  'intel': 42099,
#  'desktop': 29455,
#  'gaming': 37106,
#  'gamer': 37104,
#  'pc': 54373,
#  'gt': 38658,
#  '740': 13461,
#  '16gb': 3966,
#  '2tb': 6955,
#  '60gb': 12043,
#  'ssd': 65054,
#  '142377': 3261,
#  'am': 17595,
#  'tech': 67752,
#  'mini': 49510,
#  'precision': 56153,
#  'pliers': 55514,
#  'modeling': 49879,
#  'wire': 73817,
#  'work': 74122,
#  'b3185': 19461,
#  'bourjois': 22165,
#  'paris': 54167,
#  'khol': 44211,
#  'contour': 26853,
#  'shadow': 62378,
#  'light': 46194,
#  'eye': 33735,
#  'pencil': 54611,
#  'eyeliner': 33754,
#  '16': 3752,
#  'hour': 40798,
#  'ctd00g': 27833,
#  'ctd80p': 27836,
#  'tdc30s': 67599,
#  'tumble': 69872,
#  'dryer': 30781,
#  'fan': 34517,
#  'motor': 50284,
#  'cooling': 26928,
#  'impellor': 41760,
#  'fiore': 35275,
#  'alexandra': 17393,
#  'patterned': 54310,
#  'tights': 68470,
#  '60': 11864,
#  'denier': 29345,
#  'slight': 63474,
#  'sheen': 62493,
#  'rose': 59764,
#  'pattern': 54309,
#  'pair': 53950,
#  'plain': 55390,
#  'hoodie': 40663,
#  'hoody': 40669,
#  'unisex': 70813,
#  'hooded': 40660,
#  'jumper': 43355,
#  'pullover': 56782,
#  'sweater': 66449,
#  'winter': 73798,
#  'gift': 37604,
#  'paisley': 53953,
#  'print': 56312,
#  'off': 52712,
#  'shoulder': 62688,
#  'turn': 69932,
#  'up': 70907,
#  'sleeve': 63442,
#  'trim': 69503,
#  'plus': 55568,
#  'size': 63077,
#  'me': 48766,
#  'to': 68772,
#  'you': 75537,
#  'tatty': 67446,
#  'teddy': 67779,
#  'take': 67247,
#  'apart': 18077,
#  'childrens': 25436,
#  'baking': 19835,
#  'cooking': 26910,
#  '511': 10739,
#  'tactical': 67188,
#  'recoil': 58490,
#  'dobby': 30172,
#  'cap': 24239,
#  'headwear': 39865,
#  'patent': 54277,
#  'snake': 63744,
#  'skin': 63213,
#  'available': 19088,
#  'different': 29734,
#  'colours': 26489,
#  'system': 66740,
#  '3083': 7223,
#  'internal': 42146,
#  'speakers': 64351,
#  '253': 6139,
#  'rug': 60149,
#  'runner': 60174,
#  'traditional': 69233,
#  'agra': 17026,
#  'hand': 39380,
#  'woven': 74175,
#  'camel': 24092,
#  'small': 63605,
#  'medium': 48845,
#  'delonghi': 29294,
#  'caple': 24261,
#  'cda': 24851,
#  'cd200': 24835,
#  '2ss': 6951,
#  'grill': 38405,
#  'pan': 54019,
#  'handle': 39407,
#  '037144': 799,
#  'hp': 40833,
#  'nx9000': 52502,
#  'hdd': 39780,
#  'hard': 39485,
#  'drive': 30709,
#  'disk': 29940,
#  'caddy': 23940,
#  '312': 7353,
#  'boombox': 22031,
#  'speaker': 64349,
#  'microphone': 49320,
#  'samsung': 61067,
#  's2': 60457,
#  's3': 60517,
#  's5': 60645,
#  'note': 52087,
#  'esp': 33190,
#  'oval': 53297,
#  'rig': 59265,
#  'rings': 59306,
#  'fishing': 35334,
#  '80gb': 14156,
#  'external': 33702,
#  'usb': 71021,
#  'ultra': 70633,
#  'slim': 63477,
#  'pocket': 55625,
#  'rhodium': 59170,
#  'cable': 23912,
#  'plated': 55445,
#  'metre': 49120,
#  'pro': 56352,
#  'spec': 64359,
#  'bolt': 21942,
#  'sprocket': 64678,
#  'nuts': 52398,
#  'x6': 74674,
#  'fit': 35347,
#  'yamaha': 75334,
#  'fzr600': 36763,
#  'genesis': 37424,
#  '1989': 4681,
#  '93': 15315,
#  'titanium': 68597,
#  'purple': 56862,
#  'reversing': 59016,
#  'parking': 54177,
#  'kit': 44364,
#  'porsche': 55837,
#  'boxster': 22215,
#  '911': 15157,
#  '996': 15670,
#  'd55': 28384,
#  'optical': 52991,
#  'illusion': 41676,
#  'mesh': 49058,
#  'insert': 42030,
#  'long': 46646,
#  'bodycon': 21869,
#  'panel': 54038,
#  'dress': 30658,
#  'exhaust': 33599,
#  'gaskets': 37191,
#  'honda': 40636,
#  'gl1500': 37727,
#  'goldwing': 38017,
#  'valkerie': 71415,
#  'vivo': 72079,
#  'per': 54682,
#  'lei': 45882,
#  'green': 38337,
#  'collagen': 26399,
#  'renewal': 58809,
#  'facials': 34417,
#  'mud': 50687,
#  'soap': 63897,
#  'pcs': 54431,
#  'volcom': 72174,
#  'johnny': 43153,
#  'ski': 63199,
#  'jacket': 42717,
#  'pink': 55191,
#  'grey': 38382,
#  'jackets': 42720,
#  'snowboard': 63832,
#  'amr1495': 17752,
#  'landrover': 45457,
#  'defender': 29215,
#  '110': 2079,
#  'fuel': 36547,
#  'tank': 67328,
#  'sender': 62014,
#  'unit': 70815,
#  'personalised': 54767,
#  'charms': 25266,
#  'markers': 48183,
#  'identifiers': 41505,
#  'hoops': 40694,
#  '2012': 5109,
#  'olympic': 52846,
#  'games': 37105,
#  'bbc': 20477,
#  'blu': 21688,
#  'ray': 58177,
#  'sealed': 61816,
#  'airblade': 17098,
#  'motorcycle': 50290,
#  'dark': 28663,
#  'smoked': 63686,
#  'flyscreen': 35766,
#  'fly': 35745,
#  'screen': 61623,
#  'scru021': 61656,
#  'stainless': 65208,
#  'steel': 65389,
#  'cz': 28199,
#  'heart': 39880,
#  'necklace': 51583,
#  'statement': 65325,
#  'vintage': 71954,
#  'inspired': 42051,
#  'collar': 26406,
#  'subaru': 65906,
#  'outback': 53259,
#  '03': 736,
#  'premium': 56192,
#  'waterproof': 73094,
#  'heavy': 39912,
#  'duty': 31069,
#  'natural': 51421,
#  'abalone': 16371,
#  'inlaid': 41977,
#  'paua': 54319,
#  'shamballa': 62408,
#  'flower': 35674,
#  'clarks': 25887,
#  'first': 35321,
#  'softly': 63953,
#  'love': 46770,
#  'helmet': 39991,
#  'extension': 33695,
#  'self': 61985,
#  'arm': 18433,
#  'mount': 50327,
#  'holder': 40553,
#  'gopro': 38074,
#  'hero': 40079,
#  'camera': 24101,
#  'wild': 73668,
#  'leopard': 45948,
#  'duvet': 31073,
#  'quilt': 57423,
#  'animal': 17889,
#  'brown': 22741,
#  'yellow': 75428,
#  'bedding': 20748,
#  'bed': 20744,
#  '21': 5335,
#  'bosch': 22097,
#  'aerotwin': 16897,
#  'passenger': 54238,
#  'flat': 35497,
#  'wiper': 73813,
#  'blade': 21517,
#  'saab': 60893,
#  'xwd': 75176,
#  'qf33501': 57195,
#  'luke': 47189,
#  'robot': 59564,
#  'corker': 27007,
#  'by': 23313,
#  'monkey': 50038,
#  'business': 23207,
#  'luckies': 47163,
#  'diy': 30023,
#  'cork': 27006,
#  'corkers': 27008,
#  'luxury': 47279,
#  'cosy': 27119,
#  'embroider': 32540,
#  'bath': 20186,
#  'beach': 20644,
#  'towels': 69086,
#  'baby': 19682,
#  'men': 48963,
#  'omax': 52860,
#  'watch': 73063,
#  'gunmetal': 38816,
#  'strap': 65673,
#  'japanese': 42812,
#  'movement': 50373,
#  'sexy': 62212,
#  'cave': 24662,
#  'girl': 37686,
#  'fancy': 34521,
#  'flinstones': 35591,
#  'cavegirl': 24663,
#  'halloween': 39322,
#  'costume': 27114,
#  'vandal': 71446,
#  'suede': 65948,
#  'bijou': 21184,
#  'omega': 52865,
#  'automatic': 19039,
#  '14k': 3432,
#  'fill': 35179,
#  'sub': 65902,
#  'seconds': 61895,
#  'dial': 29653,
#  'metallic': 49089,
#  'glossy': 37850,
#  'inkjet': 41969,
#  'printable': 56313,
#  'adhesive': 16731,
#  'film': 35193,
#  'a4': 16131,
#  'sheets': 62508,
#  'micron': 49312,
#  'ttid': 69804,
#  'crank': 27407,
#  '46798345': 9789,
#  'good': 38043,
#  'used': 71037,
#  'f48': 33999,
#  'happy': 39474,
#  'tag': 67206,
#  'woof': 74097,
#  'cat': 24570,
#  'fairy': 34475,
#  'campers': 24137,
#  'caravan': 24311,
#  'dusky': 31051,
#  'suedette': 65951,
#  'ex': 33514,
#  'atmosphere': 18881,
#  '70s': 13175,
#  'cotton': 27139,
#  'short': 62667,
#  'summer': 66017,
#  'tunic': 69896,
#  'ldrs': 45723,
#  '97roll': 15579,
#  'lg': 46068,
#  'lt600p': 47043,
#  'compatible': 26628,
#  'water': 73072,
#  'filter': 35200,
#  'cheapest': 25304,
#  'the': 68179,
#  'x4': 74588,
#  'grunge': 38519,
#  'skateboarding': 63161,
#  '003': 125,
#  'ecko': 31923,
#  'corpus': 27046,
#  'star': 65268,
#  'relaxed': 58708,
#  'jeans': 42912,
#  'is': 42356,
#  'time': 68509,
#  'money': 50020,
#  'bridesmaid': 22568,
#  'maid': 47852,
#  'honour': 40657,
#  'candle': 24178,
#  'weddings': 73276,
#  'hydraulic': 41210,
#  'strut': 65809,
#  'spring': 64662,
#  'compressor': 26664,
#  'station': 65331,
#  '2200lbs': 5529,
#  'rolls': 59683,
#  'zinc': 76057,
#  'curtain': 28004,
#  'brackets': 22378,
#  'kh400': 44192,
#  'engine': 32821,
#  'covers': 27226,
#  'a2': 15983,
#  'allen': 17456,
#  'screws': 61643,
#  'vax': 71532,
#  'mach': 47700,
#  'terrain': 67938,
#  'c91': 23845,
#  'm5': 47543,
#  'at': 18788,
#  'turbo': 69915,
#  'head': 39813,
#  'tool': 68914,
#  '30': 7034,
#  'kc2746': 43910,
#  'np': 52142,
#  'kenneth': 44055,
#  'cole': 26383,
#  'stainlesss': 65209,
#  'dunlop': 30997,
#  'twin': 70062,
#  'gusset': 38833,
#  'warm': 72981,
#  'comfy': 26567,
#  'shoe': 62637,
#  'slippers': 63519,
#  '12': 2456,
#  'mathews': 48371,
#  'youth': 75545,
#  'bow': 22180,
#  'rh': 59143,
#  'archery': 18347,
#  'maneki': 48011,
#  'neko': 51623,
#  'lucky': 47164,
#  'fortune': 36008,
#  'waving': 73130,
#  'eyes': 33761,
#  'rrp': 59946,
#  '15': 3462,
#  'cat175': 24572,
#  'amazing': 17641,
#  'grass': 38286,
#  'superfood': 66152,
#  'blend': 21578,
#  '482g': 10069,
#  'super': 66112,
#  'fruits': 36375,
#  'veggies': 71627,
#  'harry': 39554,
#  'potter': 55926,
#  'gryffindor': 38526,
#  'crest': 27487,
#  'magnet': 47810,
#  'trixes': 69566,
#  'wallet': 72915,
#  'magnetic': 47813,
#  'flip': 35597,
#  'rubber': 60101,
#  'back': 19709,
#  '5g': 11685,
#  'lovely': 46781,
#  'aziba': 19268,
#  'harlequin': 39527,
#  'fabric': 34395,
#  'cushion': 28021,
#  'x16': 74480,
#  '41cm': 9158,
#  'tungsten': 69895,
#  'skull': 63261,
#  'putter': 56889,
#  'headcover': 39820,
#  'scotty': 61581,
#  'cameron': 24105,
#  'odyssey': 52691,
#  'taylormade': 67471,
#  'candure': 24186,
#  'nail': 51315,
#  'cuticle': 28047,
#  'spoon': 64590,
#  'pusher': 56877,
#  'remover': 58784,
#  'nipper': 51894,
#  'clipper': 26046,
#  'yoshimura': 75536,
#  'oil': 52766,
#  'filler': 35182,
#  'vt125': 72417,
#  '1998': 4701,
#  '2002': 5033,
#  'tutu': 69976,
#  'rara': 58108,
#  'skirt': 63232,
#  'trimmed': 69510,
#  'goth': 38104,
#  'jewellery': 43008,
#  'making': 47906,
#  'hematite': 40006,
#  'tube': 69831,
#  '14x10mm': 3457,
#  '37887': 8356,
#  '130': 2876,
#  'mk2': 49680,
#  'driveshaft': 30716,
#  'side': 62800,
#  '2x': 6978,
#  'signal': 62850,
#  'indicator': 41864,
#  'lights': 46220,
#  'amber': 17650,
#  'bulb': 23064,
#  '581': 11505,
#  'py21w': 56959,
#  'citroen': 25737,
#  'c2': 23489,
#  'psy': 56678,
#  'cardboard': 24342,
#  'cutout': 28055,
#  'standup': 65254,
#  'standee': 65248,
#  '61cm': 12186,
#  '2ft': 6842,
#  '32gb': 7617,
#  '31st': 7464,
#  'half': 39304,
#  'pence': 54609,
#  'cufflinks': 27928,
#  '1565': 3636,
#  'lpg': 46876,
#  'jeep': 42919,
#  'grand': 38236,
#  'cherokee': 25369,
#  'ii': 41609,
#  'synoquin': 66719,
#  'breed': 22511,
#  '10kg': 2000,
#  '90': 14912,
#  'sprinkle': 64668,
#  'capsules': 24284,
#  'base': 20121,
#  'pineapple': 55179,
#  'navy': 51471,
#  'khaki': 44198,
#  'disney': 29947,
#  'traditions': 69236,
#  '4039074': 8932,
#  'jessie': 42970,
#  'bullseye': 23089,
#  'story': 65628,
#  'cowgirl': 27240,
#  'horse': 40741,
#  '2014': 5117,
#  'unusual': 70897,
#  'dollar': 30238,
#  'design': 29438,
#  'cute': 28043,
#  'handy': 39433,
#  'litte': 46401,
#  'clip': 26039,
#  'coin': 26365,
#  'purse': 56869,
#  'under': 70738,
#  'trainer': 69260,
#  'socks': 63918,
#  'twilight': 70060,
#  'fierce': 35135,
#  's15': 60433,
#  'wifi': 73646,
#  'w7': 72747,
#  'quad': 57317,
#  '40ghz': 9025,
#  '1tb': 4938,
#  '1gb': 4824,
#  'graphics': 38281,
#  'fiat': 35100,
#  'punto': 56820,
#  'doblo': 30175,
#  'fiorino': 35278,
#  'window': 73740,
#  'regulator': 58671,
#  'repair': 58832,
#  'clips': 26051,
#  's3027': 60522,
#  'danyeyi': 28642,
#  'fitted': 35358,
#  'crew': 27498,
#  'neck': 51580,
#  'shirt': 62608,
#  'tee': 67783,
#  'xl': 74932,
#  'r77': 57778,
#  'carbon': 24323,
#  'race': 57883,
#  'cans': 24218,
#  'z1000': 75683,
#  'sx': 66548,
#  '2011': 5107,
#  '2013': 5110,
#  'balance': 19844,
#  'classic': 25900,
#  'traditionnels': 69235,
#  'teal': 67724,
#  'trainers': 69261,
#  'transdermal': 69291,
#  'magnesium': 47809,
#  'chloride': 25507,
#  '31': 7300,
#  '200ml': 5073,
#  'spray': 64647,
#  'pure': 56837,
#  'mineral': 49505,
#  '02131': 553,
#  '102011': 1710,
#  'aluminium': 17575,
#  'steering': 65401,
#  'hsp': 40945,
#  'upgrades': 70926,
#  'danish': 28635,
#  'cream': 27442,
#  'art': 18519,
#  'deco': 29157,
#  'pillar': 55145,
#  'dripping': 30706,
#  'candles': 24181,
#  'mezuzah': 49148,
#  'mezuza': 49147,
#  'judaica': 43307,
#  'kabbalah': 43695,
#  'israel': 42445,
#  'jewish': 43014,
#  'hebrew': 39916,
#  'ten': 67871,
#  'abarth': 16372,
#  'grande': 38241,
#  'hinge': 40319,
#  'door': 30315,
#  'gate': 37203,
#  '100mm': 1615,
#  'inch': 41821,
#  'hometek': 40626,
#  'home': 40611,
#  'tek': 67806,
#  'elite': 32422,
#  'eco': 31932,
#  'ht824': 40974,
#  'ht855': 40980,
#  'ht829': 40976,
#  'ht859': 40981,
#  'ht838': 40977,
#  'steam': 65377,
#  'mop': 50150,
#  'cleaning': 25942,
#  'pads': 53909,
#  ...}

# %%
from sklearn.feature_extraction.text import CountVectorizer
import re

def clean_text(t):
    t = t.lower()
    t = re.sub("[^A-Za-z0-9]"," ",t)
    t = re.sub("[0-9]+","#",t)
    return t

vectorizers = [
     ("vanilla",
          CountVectorizer())
    ,("preprocessing",
          CountVectorizer(preprocessor=clean_text))
    ,("preprocessing + min_df=10",
          CountVectorizer(preprocessor=clean_text,
                          min_df=10))
]

for vect_name, vect in vectorizers:
    print(vect_name)
    vect.fit(X_tr)
    
    print(list(vect.vocabulary_)[:10])
    print(len(vect.vocabulary_))
# Out:
# vanilla
# ['new', 'apple', 'iphone', '6th', 'generation', 'inch', 'blue', 'gel', 'silicone', 'case']
# 71734
# preprocessing
# ['new', 'apple', 'iphone', 'th', 'generation', 'inch', 'blue', 'gel', 'silicone', 'case']
# 39680
# preprocessing + min_df=10
# ['new', 'apple', 'iphone', 'th', 'generation', 'inch', 'blue', 'gel', 'silicone', 'case']
# 7519

# %% [markdown]
# <a>Double click to show the solution</a>
# <div class='spoiler'>
#
# from sklearn.feature_extraction.text import CountVectorizer
# import re
#
# def clean_text(t):
#     t = t.lower()
#     t = re.sub("[^A-Za-z0-9]"," ",t)
#     t = re.sub("[0-9]+","#",t)
#     return t
#
# vectorizers = [
#      ("vanilla",
#           CountVectorizer())
#     ,("preprocessing",
#           CountVectorizer(preprocessor=clean_text))
#     ,("preprocessing + min_df=10",
#           CountVectorizer(preprocessor=clean_text,
#                           min_df=10))
# ]
#
# for vect_name, vect in vectorizers:
#     print(vect_name)
#     vect.fit(X_tr)
#
#     print(list(vect.vocabulary_)[:10])
#     print(len(vect.vocabulary_))
#
# </div>

# %% [markdown]
# Stemming
# ------------------
#
# Linguistic normalization in which variant forms are reduced to a common form
#
#     connection
#     connections
#     connective     --->   connect
#     connected
#     connecting
#
# Usage:
#
#     import snowballstemmer
#
#     stemmer = snowballstemmer.stemmer('english')
#     print(stemmer.stemWords("We are the world".split()))

# %% [markdown]
# **How to make preprocessing faster?**
#
# There is map a function.
# Below there is a comparison of three methods from the most naive to the fastest.

# %% [markdown]
# Using a loop

# %%
# %%time
preprocessed_naive = X_tr[:]
for n in range(preprocessed_naive.shape[0]):
    preprocessed_naive[n] = clean_text(preprocessed_naive[n])
# Out:
# CPU times: user 624 ms, sys: 0 ns, total: 624 ms
# Wall time: 624 ms

# %% [markdown]
# Using ```map``` function

# %%
# %%time 
preprocessed_map = map(clean_text, X_tr)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 11.2 µs

# %% [markdown]
# Using ```pool.map``` function

# %%
# %%time
from multiprocessing import Pool

pool = Pool(8)
preprocessed_poolmap = pool.map(clean_text, X_tr)
pool.close()
# Out:
# CPU times: user 84 ms, sys: 128 ms, total: 212 ms
# Wall time: 359 ms

# %% [markdown]
# Putting it into a pipeline
# ----------------------
#
# Now that we know how to transform text data, let's put it into a pipeline.
#
# 1. Create a pipeline with `CountVectorizer`, `StandardScaler` and `SGDClassifier` as your final algorithm
#     a) use alternative format for pipeline definition when you name the steps - refer to the documentation how to do this
# 2. Using ```sklearn.metrics.classification_report``` create a report about your classifier

# %%
##########################
# put your solution here #
##########################

from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.cross_validation import cross_val_predict
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.grid_search import GridSearchCV

clf = Pipeline([('vect', CountVectorizer(min_df=10, preprocessor=clean_text)),
                ('scaling', StandardScaler(with_mean=False)),
                ('clf', GridSearchCV(SGDClassifier(), param_grid={"alpha":[0.1,0.01,0.001]}))])

preds = cross_val_predict(clf, 
                          X_tr, 
                          y_tr, 
                          cv=8, n_jobs=-1, verbose=True)

def add_padding(t):
    return t.rjust(30)

print(classification_report(list(map(add_padding, y_tr)), 
                            list(map(add_padding, preds))))
# Out:
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:  1.3min remaining:  4.0min
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:  1.3min finished
#                                 precision    recall  f1-score   support
#
#                            Art       0.63      0.66      0.64       504
#                           Baby       0.82      0.60      0.69       587
#                          Music       0.90      0.92      0.91      1223
#                         Crafts       0.83      0.81      0.82      3062
#                         Stamps       0.81      0.79      0.80        97
#                         Travel       0.00      0.00      0.00         2
#                       Antiques       0.51      0.12      0.20       156
#                   Collectibles       0.76      0.66      0.71      2274
#                   Pet Supplies       0.83      0.73      0.78       615
#                   Toys & Games       0.84      0.76      0.80      2623
#                  Dolls & Bears       0.86      0.84      0.85       259
#                 Garden & Patio       0.79      0.67      0.73       969
#                 Sound & Vision       0.75      0.71      0.73      1729
#                 Sporting Goods       0.84      0.72      0.77      4179
#                Everything Else       0.76      0.42      0.54       163
#                Health & Beauty       0.81      0.84      0.83      2981
#               DVDs, Films & TV       0.80      0.92      0.85       528
#              Holidays & Travel       0.00      0.00      0.00         3
#             Sports Memorabilia       0.79      0.56      0.65       240
#            Coins & Paper Money       0.84      0.83      0.84       196
#            Jewellery & Watches       0.92      0.97      0.94      5517
#           Consumer Electronics       0.66      0.18      0.28       118
#           Wholesale & Job Lots       0.65      0.50      0.57        82
#          Cameras & Photography       0.88      0.80      0.84       772
#          Home, Furniture & DIY       0.84      0.87      0.85     11518
#         Video Games & Consoles       0.84      0.71      0.77       399
#      Books, Comics & Magazines       0.82      0.69      0.75       387
#      Cell Phones & Accessories       0.79      0.22      0.34        68
#      Entertainment Memorabilia       0.00      0.00      0.00         6
#     Musical Instruments & Gear       0.81      0.50      0.62       414
#     Pottery, Porcelain & Glass       0.78      0.43      0.55        91
#    Vehicle Parts & Accessories       0.93      0.97      0.95     20923
#   Clothes, Shoes & Accessories       0.91      0.96      0.93     15162
#  Business, Office & Industrial       0.73      0.54      0.62      2494
#  Mobile Phones & Communication       0.87      0.93      0.90      3569
# Computers/Tablets & Networking       0.92      0.92      0.92      6090
#
#                    avg / total       0.87      0.88      0.87     90000

# %% [markdown]
# <a>Double click to show the solution</a>
# <div class='spoiler'>
#
# from sklearn.pipeline import Pipeline
# from sklearn.linear_model import SGDClassifier
# from sklearn.cross_validation import cross_val_predict
# from sklearn.metrics import classification_report
# from sklearn.preprocessing import StandardScaler
# from sklearn.grid_search import GridSearchCV
#
# clf = Pipeline([('vect', CountVectorizer(min_df=10, preprocessor=clean_text)),
#                 ('scaling', StandardScaler(with_mean=False)),
#                 ('clf', GridSearchCV(SGDClassifier(), param_grid={"alpha":[0.1,0.01,0.001]}))])
#
# preds = cross_val_predict(clf,
#                           X_tr,
#                           y_tr,
#                           cv=8, n_jobs=-1, verbose=True)
#
# def add_padding(t):
#     return t.rjust(30)
#
# print(classification_report(list(map(add_padding, y_tr)),
#                             list(map(add_padding, preds))))
#
#
# </div>

# %% [markdown]
# Grid search
# --------------------------
#
# Scikit-learn has `GridSearchCV` and `RandomizedSearchCV`. Both have the same functionality and can be used to find good parameters for the models. What is great about both these classes that they are both transformers - they return an estimator so you can chain them and put in your pipeline.
#
# **GridSearchCV** - you specify the exact values of the parameters you want to test
# **RandomizedSearchCV** - you specify ranges of parameters
#
# Exercise
# ----------------------
#
# 1. Use `GridSearchCV` or `RandomizedSearchCV` to find the best parameters for the models. Check at least 2 parameters.

# %%
##########################
# put your solution here #
##########################s

from sklearn.grid_search import GridSearchCV, RandomizedSearchCV

print("Grid search")
print()

params = {'vect__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4)],
          'vect__analyzer': ["word","char"],
          'vect__binary': [True, False]}

grid_clf = GridSearchCV(clf, params, n_jobs=1, verbose=True)
grid_clf.fit(X_tr, y_tr)

best_params = sorted(grid_clf.grid_scores_, key=lambda x: -x[1])


for params, score, _ in best_params:
    print(score, params) 
    
print("Randomized search")
print()
    
params = {'vect__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4)],
          'vect__analyzer': ["word","char"],
          'model__lr__dimensions': [100, 200]}

grid_clf = RandomizedSearchCV(clf, params, n_jobs=1, verbose=True, n_iter=8)
grid_clf.fit(np.array(X_tr[:10000]), y_tr[:10000])

best_params = sorted(grid_clf.grid_scores_, key=lambda x: -x[1])

for params, score, _ in best_params:
    print(score, params)
# Out:
# Grid search
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits

# %% [markdown]
# <a>Double click to show the solution</a>
# <div class='spoiler'>
#
# from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
#
# print("Grid search")
# print()
#
# params = {'vect__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4)],
#           'vect__analyzer': ["word","char"],
#           'vect__binary': [True, False]}
#
# grid_clf = GridSearchCV(clf, params, n_jobs=1, verbose=True)
# grid_clf.fit(X_tr, y_tr)
#
# best_params = sorted(grid_clf.grid_scores_, key=lambda x: -x[1])
#
#
# for params, score, _ in best_params:
#     print(score, params)
#
# print("Randomized search")
# print()
#
# params = {'vect__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4)],
#           'vect__analyzer': ["word","char"],
#           'model__lr__dimensions': [100, 200]}
#
# grid_clf = RandomizedSearchCV(clf, params, n_jobs=1, verbose=True, n_iter=8)
# grid_clf.fit(np.array(X_tr[:10000]), y_tr[:10000])
#
# best_params = sorted(grid_clf.grid_scores_, key=lambda x: -x[1])
#
# for params, score, _ in best_params:
#     print(score, params)
#
# </div>

# %% [markdown]
# Useful materials
#
# 1. http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
# 2. http://scikit-learn.org/stable/auto_examples/model_selection/randomized_search.html
